# %% [markdown]
# # **Задание 2. Формирование иерархической структуры проекта в контексте управления проектами информационных систем**

# %% [markdown]
# ```
#
# 1. ОБЗОР ПРЕДМЕТНОЙ ОБЛАСТИ И СУЩЕСТВУЮЩИХ РЕШЕНИЙ
#     1.1. Исследование текущего состояния систем создания квизов и тестовых заданий
#      1.1.1. Существующие подходы к автоматической генерации вопросов и созданию образовательных тестов
#     1.2. Обзор существующих платформ и сервисов для создания квизов
#      1.2.1. Отечественные решения
#      1.2.2. Зарубежные аналоги
#     1.3. Обзор технологий разработки веб-платформ с элементами обработки естественного языка
#      1.3.1. Современные языки программирования и фреймворки для создания интеллектуальных веб-приложений
#      1.3.2. Платформы развертывания
#      1.3.3. Подходы к созданию систем автоматической генерации контента
#
# 2. АНАЛИЗ ТРЕБОВАНИЙ И ПРОЕКТИРОВАНИЕ ПЛАТФОРМЫ
#     2.1. Сравнительный анализ существующих решений и выявление их недостатков
#      2.1.1. Функциональные ограничения существующих платформ
#      2.1.2. Проблемы производительности, масштабируемости и применимости существующих систем
#     2.2. Обоснование выбора технологического стека для разрабатываемой платформы
#      2.2.1. Выбор и обоснование языков программирования и основных фреймворков
#      2.2.2. Определение архитектуры системы и выбор платформы развёртывания
#     2.3. Формирование функциональных и нефункциональных требований к системе
#      2.3.1. Функциональные требования и основные пользовательские сценарии (диаграмма вариантов использования, диаграмма деятельности)
#      2.3.2. Нефункциональные требования к платформе
#
# 3. ПРОЕКТИРОВАНИЕ И РЕАЛИЗАЦИЯ СИСТЕМЫ
#     3.1. Проектирование архитектуры
#      3.1.1. Проектирование структуры базы данных для хранения пользователей, документов и квизов (ER-диаграмма)
#      3.1.2. Проектирование модулей системы и их взаимосвязей (диаграмма классов)
#      3.1.3. UML-диаграммы взаимодействия компонентов системы (диаграмма компонентов, диаграмма последовательности, диаграмма состояний)
#     3.2. Программная реализация платформы
#      3.2.1. Разработка серверной части
#      3.2.2. Создание пользовательского интерфейса для работы с квизами
#      3.2.3. Интеграция с внешними системами и реализация API для экспорта
#     3.3. Тестирование
#      3.3.1. Развёртывание системы в облачном окружении
#      3.3.2. Функциональное тестирование основных пользовательских сценариев
#      3.3.3. Нагрузочное тестирование и оценка производительности системы
#      3.3.4. Оценка качества автоматически генерируемых квизов и точности
#
# ```
