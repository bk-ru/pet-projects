# %% [markdown]
# # **Задание №3. Разработка UML-диаграмм для проектирования информационной системы**

# %% [markdown]
# ## **Цель задания**

# %% [markdown]
# На основе ранее разработанной концептуальной основы дипломного проекта спроектировать основные UML-диаграммы, необходимые для моделирования вашей информационной системы.

# %% [markdown]
# ### **1. Диаграмма классов**

# %% [markdown]
# ![Untitled diagram-2025-10-22-080135.png](data:image/png;base64,...)

# %% [markdown]
# ### **2. Диаграмма вариантов использования**

# %% [markdown]
# ![загруженное.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **3. Диаграмма последовательности**

# %% [markdown]
# ![Untitled diagram-2025-10-22-082652.png](data:image/png;base64,...)

# %% [markdown]
# ### **6. Диаграмма компонентов**

# %% [markdown]
# ![Untitled diagram-2025-10-22-082811.png](data:image/png;base64,...)
